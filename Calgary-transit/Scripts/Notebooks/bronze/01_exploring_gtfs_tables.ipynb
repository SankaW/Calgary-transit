# %% [markdown]
# https://data.calgary.ca/Transportation-Transit/Calgary-Transit-Realtime-Trip-Updates-GTFS-RT/gs4m-mdc2/about_data
#
# https://gtfs.org/documentation/schedule/reference/

# %%
# %sql
SELECT _ingest_date, COUNT(*)
FROM calgary_transit.bronze.gtfs_agency
GROUP BY _ingest_date
ORDER BY _ingest_date;

# %%
# %sql
SELECT *
FROM calgary_transit.bronze.gtfs_agency

# %%
# %sql
SELECT _ingest_date, COUNT(*)
FROM calgary_transit.bronze.gtfs_trips
GROUP BY _ingest_date
ORDER BY _ingest_date;

# %%
# %sql
SELECT *
FROM calgary_transit.bronze.gtfs_trips
