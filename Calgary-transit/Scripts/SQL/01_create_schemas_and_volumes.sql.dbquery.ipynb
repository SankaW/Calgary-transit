-- %%
CREATE CATALOG calgary_transit;

CREATE SCHEMA IF NOT EXISTS calgary_transit.landing;
CREATE SCHEMA IF NOT EXISTS calgary_transit.bronze;

CREATE VOLUME IF NOT EXISTS calgary_transit.landing.landing_vol;
CREATE VOLUME IF NOT EXISTS calgary_transit.bronze.bronze_vol;
